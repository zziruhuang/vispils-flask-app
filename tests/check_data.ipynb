# %%
import pandas as pd
from rdkit import Chem
from rdkit.Chem import Draw
from IPython.display import display

# %%
df = pd.read_csv('../vispils/data/vispils-v1.csv')

# %%
df.head()
# Out:
#                                           Iso SMILES  GC Pred.  \
# 0  BrC=C(Br)Cn1cc[n+](CC(Br)CBr)c1.Br[Al-](Br)(Br)Br       NaN
# 1  BrC=C(Br)Cn1cc[n+](CC(Br)CBr)c1.Br[Fe-](Br)(Br)Br       NaN
# 2  BrC=C(Br)Cn1cc[n+](CC(Br)CBr)c1.Brc1ccc2[n-]cn...       NaN
# 3  BrC=C(Br)Cn1cc[n+](CC(Br)CBr)c1.C=C1O[B-](F)(F...       NaN
# 4     BrC=C(Br)Cn1cc[n+](CC(Br)CBr)c1.C=C[B-](F)(F)F       NaN
#
#                 aSMILES afam1 afam_class  aCenterValence  aElectronegativity  \
# 0     Br[Al-](Br)(Br)Br   mln        mln               4                1.61
# 1     Br[Fe-](Br)(Br)Br   mln        mln               4                1.83
# 2    Brc1ccc2[n-]cnc2c1   cyc        cyc               2                3.04
# 3  C=C1O[B-](F)(F)OC1=C     b        mln               4                2.04
# 4        C=C[B-](F)(F)F     b        mln               4                2.04
#
#    aCenterSize  aSymmetry  aOxyAnions  ...               Anion|cfam  \
# ...

# %%
df['Temperature'].unique()
# Out:
# array([298.15, 298.  , 298.2 , 298.1 , 298.13, 298.24, 298.3 , 298.05])
